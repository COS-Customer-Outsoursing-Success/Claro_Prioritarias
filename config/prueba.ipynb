# %%
filepath = r"C:/01_github/Axa/data/asignacion/nueva/asignacion_willis/02102025_BD CALL CENTER RENOVACIONES PLAN CAIDAS_01 AL 30 DE NOVIEMBRE_EC.xlsx"
import pandas as pd
df = pd.read_excel(filepath, sheet_name="01 AL 30 DE SEPTIEMBRE")

# %%
df
# Out:
#    Placa Vehiculo  Identificación Cliente                    Nombre Cliente  \
# 0          DQX990                10121524         LOPEZ MARIN LUIS FERNANDO
# 1          ELV089                52516755       QUINTERO RUBIANO LINA MARIA
# 2          ELV824                52882438     VALERO GUTIERREZ YANETH ROCIO
# 3          ENX670                43523132  ANDRADE QUINTERO SANDRA PATRICIA
# 4          GFM344                43552976      OSPINA RAMIREZ IVONNE YANETH
# 5          GRM751                43754645   CIFUENTES LOPERA GLORIA CECILIA
# 6          HBZ082                36305171     SEPULVEDA POLANCO ANA DAMARIS
# 7          HGL011                11293280          SANTOFIMIO TORRES ALVARO
# 8          IBE97G                80056119        BOHORQUEZ FONTECHA ALEICER
# 9          JMY553              1020762769               PEREZ ZAUNER ANDREA
# 10         JWY920                41557915      HIDALGO DE AFANADOR CONSUELO
# ...

# %%
df['Field'] = df['Field'].apply(lambda row: "'" +row +"',")
df['Field'].to_csv('Resultados.csv')
